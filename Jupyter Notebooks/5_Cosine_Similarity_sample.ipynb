# %%
test = True

# %%
# Step 1: Import libraries
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Step 2: Load my embeddings that are already done
if test == True:
   	url_songs = 'https://drive.google.com/file/d/1OYu-bt9GQQ_q1SJ1295w4RmzH-nXAcs7/view?usp=sharing'
else:
    url_songs = 'url de todo junto'
path_songs = 'https://drive.google.com/uc?export=download&id='+url_songs.split('/')[-2]
song_embeddings = pd.read_csv(path_songs)

url_events = 'https://drive.google.com/file/d/1qYjdla35SWFpPFBi24uIJXzErMIGWQUi/view?usp=sharing'
path_events = 'https://drive.google.com/uc?export=download&id='+url_events.split('/')[-2]
event_embeddings = pd.read_csv(path_events)

# %%
event_embeddings.head(1)
# Out:
#    EventCode    dim_0     dim_1     dim_2     dim_3    dim_4     dim_5  \
# 0       1413 -0.02164  0.092606  0.000398 -0.010073 -0.01941  0.073137
#
#       dim_6     dim_7     dim_8  ...   dim_374   dim_375   dim_376   dim_377  \
# 0  0.019721  0.018777 -0.044716  ...  0.084632  0.086719  0.000282  0.004671
#
#     dim_378   dim_379   dim_380   dim_381   dim_382   dim_383
# 0 -0.062479  0.066642  0.126728  0.185229  0.001672  0.027591
#
# [1 rows x 385 columns]

# %%
song_embeddings.head(1)
# Out:
#    song_id        Q1        Q2        Q3        Q4        Q5        Q6  \
# 0    68827 -0.072764 -0.092227  0.059105 -0.044525 -0.078067  0.057185
#
#          Q7        Q8        Q9  ...      Q375     Q376      Q377      Q378  \
# 0  0.102446 -0.054466  0.041038  ...  0.094456  0.01942  0.038416  0.129572
#
#        Q379      Q380      Q381      Q382      Q383      Q384
# 0 -0.007244  0.014351 -0.045571  0.024775 -0.001791 -0.056692
#
# [1 rows x 385 columns]

# %%
# Step 3: Make sure that we're only using the vectors (384 numeric columns)
# If there are columns like 'song' or 'event', we eliminate them
song_vectors = song_embeddings.drop(columns=['song_id']).values
event_vectors = event_embeddings.drop(columns=['EventCode']).values

# %%
song_vectors
# Out:
# array([[-0.07276378, -0.092227  ,  0.05910474, ...,  0.02477457,
#         -0.00179082, -0.05669229],
#        [-0.02295917, -0.03520459,  0.00577369, ...,  0.10094515,
#         -0.01068587,  0.02344048],
#        [-0.0382315 , -0.08062958,  0.05640888, ..., -0.00597885,
#         -0.05668112,  0.02637054],
#        ...,
#        [-0.04870946, -0.08592204, -0.00696632, ...,  0.03459693,
#          0.01405263, -0.03262225],
#        [-0.01083324, -0.07321788,  0.07286011, ...,  0.03422752,
#          0.03246599, -0.05281978],
#        [-0.05530139, -0.08141771,  0.02030162, ...,  0.00165738,
#          0.01397387, -0.06657673]])

# %%
# Step 4: Calculate the cosine similarity matrix
similarity_matrix = cosine_similarity(song_vectors, event_vectors)

# %%
# Step 5: Create df
similarity_df = pd.DataFrame(similarity_matrix,
                             index=song_embeddings['song_id'],
                             columns=event_embeddings['EventCode'])

# %%
similarity_df.shape[0], similarity_df.shape[1]
# Out:
# (1000, 27)

# %%
similarity_df.head(10)
# Out:
# EventCode      1413      1414      1431      1432      1433      1434  \
# song_id
# 68827      0.054829 -0.020995  0.001726  0.034114  0.065783  0.026820
# 8701       0.080045  0.029493 -0.011937  0.036954  0.063092  0.002647
# 312626     0.117203 -0.046293  0.014552  0.015431  0.053146 -0.020668
# 71018      0.080494 -0.016610 -0.073499 -0.077947 -0.039458 -0.097725
# 275790     0.087898 -0.005446  0.092211  0.085383  0.104728  0.073747
# 161459     0.048731  0.011429 -0.009566  0.000539  0.016674 -0.025199
# 93431      0.007120  0.005617  0.009591 -0.018991 -0.003350 -0.021777
# 304151     0.093095 -0.003491  0.013720 -0.011199  0.047365 -0.010660
# 82240      0.071139  0.033463  0.081042  0.080406  0.100743  0.106589
# 231332     0.111759  0.038321  0.072963  0.032068  0.071253  0.050184
#
# EventCode      1451      1452      1453      1454  ...      192       193   \
# song_id                                            ...
# ...

# %%
similarity_df.describe()
# Out:
# EventCode         1413         1414         1431         1432         1433  \
# count      1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean          0.099667     0.018397     0.063762     0.058323     0.091612
# std           0.052204     0.058457     0.054315     0.053481     0.053917
# min          -0.043620    -0.139558    -0.075308    -0.092507    -0.077454
# 25%           0.063960    -0.020959     0.027277     0.022251     0.056908
# 50%           0.094997     0.013121     0.062077     0.059100     0.092432
# 75%           0.131291     0.051946     0.094036     0.089787     0.122447
# max           0.293883     0.290054     0.293792     0.281843     0.349095
#
# EventCode         1434         1451         1452         1453         1454  \
# count      1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean          0.054570     0.094659     0.079005     0.113235     0.074247
# ...

# %%
similarity_df.head(1)
# Out:
# EventCode      1413      1414      1431      1432      1433     1434  \
# song_id
# 68827      0.054829 -0.020995  0.001726  0.034114  0.065783  0.02682
#
# EventCode      1451      1452      1453     1454  ...      192       193   \
# song_id                                           ...
# 68827      0.026753  0.042236  0.075437  0.03486  ...  0.030676  0.091197
#
# EventCode      194       196       200       201       202       203   \
# song_id
# 68827     -0.003172 -0.043017  0.071874 -0.021605  0.020304 -0.045844
#
# EventCode      2041      2042
# song_id
# 68827     -0.014506  0.105905
#
# [1 rows x 27 columns]

# %%
# similarity_df.set_index('EventCode', inplace=True)

# %%
# # So that the index gets saved as well
# similarity_df.set_index('song', inplace=True)
# Step 6: Save results
# similarity_df.to_csv("similarity_df.csv", index=False)
similarity_df.to_csv("similarity_df.csv", index=True)

# Descargar el archivo
from google.colab import files
files.download("similarity_df.csv")

# %%
similarity_df.head(5)
# Out:
# EventCode      1413      1414      1431      1432      1433      1434  \
# song_id
# 68827      0.054829 -0.020995  0.001726  0.034114  0.065783  0.026820
# 8701       0.080045  0.029493 -0.011937  0.036954  0.063092  0.002647
# 312626     0.117203 -0.046293  0.014552  0.015431  0.053146 -0.020668
# 71018      0.080494 -0.016610 -0.073499 -0.077947 -0.039458 -0.097725
# 275790     0.087898 -0.005446  0.092211  0.085383  0.104728  0.073747
#
# EventCode      1451      1452      1453      1454  ...      192       193   \
# song_id                                            ...
# 68827      0.026753  0.042236  0.075437  0.034860  ...  0.030676  0.091197
# 8701      -0.041458 -0.023995  0.007328 -0.042182  ...  0.095251 -0.019907
# 312626     0.032391  0.020756  0.051618 -0.011077  ...  0.069201  0.147861
# 71018      0.013961 -0.007130  0.021176 -0.018876  ...  0.038949  0.248068
# 275790     0.095739  0.073693  0.109842  0.053039  ...  0.099455  0.019448
#
# ...

# %%
import pandas as pd
import numpy as np

# Aplanamos la matriz manteniendo los índices
stacked = similarity_df.stack()

# Obtenemos los 4 valores más bajos
lowest = stacked.nsmallest(4)
# Obtenemos los 4 valores más altos
highest = stacked.nlargest(4)

# Mostramos resultados
print("🔻 Canciones con menor similaridad:")
print(lowest)

print("\n🔺 Canciones con mayor similaridad:")
print(highest)
# Out:
# 🔻 Canciones con menor similaridad:
# song_id  EventCode
# 28924    190         -0.186555
# 329144   190         -0.173248
# 375321   190         -0.169361
# 168540   190         -0.168051
# dtype: float64
#
# 🔺 Canciones con mayor similaridad:
# song_id  EventCode
# 127899   1453         0.415014
# 43992    175          0.405246
# 296572   1453         0.388978
# 127899   1454         0.373755
# dtype: float64

# %%
# Asegurarse de que el índice sea simple
similarity_df_reset = similarity_df.reset_index()

# Obtener song_index correcto antes de apilar
similarity_df_reset['song_index'] = similarity_df_reset.index

# Apilar matriz para tener song, EventCode, similarity
stacked_df = similarity_df_reset.set_index(['song_index', 'song_id']).stack().reset_index()
stacked_df.columns = ['song_index', 'song_id', 'EventCode', 'similarity']

# Filtrar canciones vacías o nulas
stacked_df = stacked_df[stacked_df['song_id'].notna() & (stacked_df['song_id'] != '')]

# Top 4 más bajos
lowest = stacked_df.nsmallest(15, 'similarity')
# Top 4 más altos
highest = stacked_df.nlargest(15, 'similarity')

# Mostrar ambos
print("🔻 Canciones con menor similaridad:")
print(lowest[['song_index', 'song_id', 'EventCode', 'similarity']])

print("\n🔺 Canciones con mayor similaridad:")
print(highest[['song_index', 'song_id', 'EventCode', 'similarity']])
# Out:
# 🔻 Canciones con menor similaridad:
#        song_index  song_id  EventCode  similarity
# 22425         830    28924        190   -0.186555
# 14190         525   329144        190   -0.173248
# 16539         612   375321        190   -0.169361
# 5172          191   168540        190   -0.168051
# 8952          331    66986        190   -0.167374
# 9276          343   110350        190   -0.163915
# 17322         641    74875        190   -0.159756
# 4875          180   381394        190   -0.155832
# 21856         809   377119        175   -0.150833
# 26934         997   242018        190   -0.150312
# 15464         572   167572        196   -0.150190
# 8331          308   350671        190   -0.146838
# 1122           41   301543        190   -0.146796
# 7737          286     6289        190   -0.143763
# 22894         847   209668       2041   -0.143563
#
# 🔺 Canciones con mayor similaridad:
#        song_index  song_id  EventCode  similarity
# ...

# %%
url_originaldf = 'https://drive.google.com/file/d/1nIcwGfU9WB2UCcflYzEhr6c9VU_-F6WH/view?usp=sharing'
path_originaldf = 'https://drive.google.com/uc?export=download&id='+url_originaldf.split('/')[-2]
#original_df = pd.read_csv(path_originaldf)

import gdown
output_original = 'original.csv'
gdown.download(url_originaldf, output_original, quiet=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1nIcwGfU9WB2UCcflYzEhr6c9VU_-F6WH
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1nIcwGfU9WB2UCcflYzEhr6c9VU_-F6WH/view?usp=sharing
# To: /content/original.csv
# 3.06kB [00:00, 3.71MB/s]
# 'original.csv'

# %%
# To import data
import gdown
# Import songs dataset
url_songs_file = 'https://drive.google.com/file/d/1pp6AwVMt2ROIMX96YPqkdmyDmMxA2G6w/view?usp=sharing'
songs_id = url_songs_file.split('/')[-2]
url_songs = f"https://drive.google.com/uc?id={songs_id}"
output_songs = "songs_clean_text.csv"
gdown.download(url_songs, output_songs, quiet=False)
# songs_lyrics = pd.read('/content/songs_clean_text.csv', encoder='python')
songs_lyrics = pd.read_csv("songs_clean_text.csv")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1pp6AwVMt2ROIMX96YPqkdmyDmMxA2G6w
# From (redirected): https://drive.google.com/uc?id=1pp6AwVMt2ROIMX96YPqkdmyDmMxA2G6w&confirm=t&uuid=fa1df00b-2c6a-4774-937b-97f827548afc
# To: /content/songs_clean_text.csv
# 100%|██████████| 1.36G/1.36G [00:13<00:00, 104MB/s]

# %%
songs_lyrics.head(1)

# %% [markdown]
# # Test

# %%
aux_df.loc[aux_df['song_id'].isin([329144,375321,168540,66986,110350,74875])]
# Out:
#         song_id                                  Artists  \
# 64779     66986                                   Weezer
# 72444     74875                          Alexandra Verna
# 106861   110350  Moneybagg Yo,YoungBoy Never Broke Again
# 163253   168540                              Trevor Hall
# 318748   329144                                The Roots
# 363387   375321                         The Wonder Years
#
#                               song  \
# 64779                  Burndt Jamb
# 72444                    Hell If I
# 106861                 Broke Again
# 163253  The Lime Tree 2009 version
# 318748      No John Trumbull Intro
# 363387         Leavenhouse. 11:30.
#
#                                                      text
# 64779   [Verse 1] Gothic flavor How I miss you If I on...
# 72444   I thought we had something special Though I mi...
# 106861  [Verse 1] Back-back in school I used to hate a...
# 163253  [Verse 1] Spark a match and watch the candle b...
# ...

# %%
aux_df = songs_lyrics[['song_id','Artists','song','text']]

# %%
aux_df.loc[aux_df['song_id'].isin([28924, 329144, 375321, 168540, 66986, 110350])]

# %%
aux_df['Artists'].unique()

# %%
pd.DataFrame({'Artist': aux_df['Artists'].dropna().unique()})

# %%
pd.DataFrame({'Artist': aux_df['Artists'].dropna().unique()}).to_csv("unique_artists.csv", index=False)

from google.colab import files
files.download("unique_artists.csv")

# %%
aux_df.loc[aux_df['Artists'].str.contains('Bob Marley', case=False, na=False)]

# %%
aux_df.loc[aux_df['Artists'] == 'Sex Pistols']

# %%
aux_df.loc[aux_df['song'].str.lower() == 'b.y.o.b.'.lower()]

# %%
aux_df.loc[aux_df['Artists'].str.contains('System of a down', case=False, na=False)]

# %%
aux_df.loc[aux_df['song'].str.lower() == 'god save the queen'.lower()]

# %%
list_99249 = [-0.034050293,0.03137639,-0.013751942,-0.04142069,-0.016881144,0.14396207,0.06138286,-0.027261928,0.010815433,0.00804828,0.022114355,-0.043791782,0.03231131,-0.042822786,-0.025716156,0.04449826,-0.04428636,0.041166153,-0.013514375,-0.027613996,0.01138959,0.09246151,-0.06569752,0.061645348,-0.09192335,0.09060175,-0.084854186,-0.01173295,0.017059814,-0.063203774,0.06530878,0.0026319847,0.043044087,-0.023789683,-0.10153499,0.041341748,0.03860937,0.05641478,0.008962404,0.017046839,-0.008276726,-0.009965662,-0.003932244,-0.10426438,0.041773852,-0.0032297354,-0.046868388,-0.08679829,0.09105562,-0.068782516,-0.03623025,-0.030632475,0.037454814,0.027204186,0.03318816,0.00028928602,-0.006159352,0.05143739,0.06539457,-0.
122,0.038262,0.022216825,0.029106239,-0.04230201,0.056802124,-0.04394036,-0.016454998,0.07776023,-0.032796018,-0.0024749583,0.035957824,0.11130875,-0.0014926433,0.010044934,-0.00021280623,-0.041038968,-0.022257559,-0.01875584,0.025379436,-0.029277883,-0.034466006,-0.019729199,0.14380792,0.0056847003,0.034238063,-0.1294241,0.0021905862,-0.03337379,-0.025196312,0.0035137532,0.12263948,-0.028783504,-0.18890953,-1.9703907e-32,-0.017490307,0.0034123834,-0.018159552,0.055326484,0.024987666,0.022954963,-0.079878435,-0.017143885,0.081359535,0.0878722,-0.017939905,-0.013066768,0.066367544,0.0037118432,0.036491815,-0.097766064,0.076914944,-0.08197539,-0.02348229,0.015790414,-0.053841658,0.03476524,-0.08723168,0.052845806,-0.07040435,0.074139394,-0.0412733,0.047688488,0.011690445,0.009927878,-0.012870276,0.024410464,-0.13386098,0.05535697,-0.0018843776,-0.06121859,0.03296365,-0.015009881,0.019983266,0.014121399,-0.05518422,-0.056516312,-0.0076337275,-0.0010120892,-0.045566794,-0.040035974,-0.06934191,0.03855827,0.1201117,0.012023918,0.018013764,-0.009163978,-0.08580291,-0.04852857,0.010415257,-0.021901403,-0.0070036934,-0.120935075,0.0031510417,0.028975694,-0.043371145,0.005827526,0.028351381,0.056004304,-0.04193537,0.036470238,-0.02551061,0.05387047,0.041578542,-0.011544861,0.020083042,-0.019743534,-0.12281224,-0.03489822,-0.06302486,-0.004680995,0.0026240337,-0.049763817,0.03440226,0.006266021,0.021698607,0.011688389,-0.033272713,-0.005002312,0.010819187,-0.03326691,0.007720409,-0.015081273,0.02883106,-0.0051835533,0.03529145,0.0290507,0.059334554,0.043909762,-0.023158388,-5.2112195e-08,-0.02718794,0.03443475,0.030665524,0.073562786,0.04834766,-0.08066411,-0.027610883,-0.047683142,-0.027361598,-0.021350663,0.071528666,0.08550559,-0.044157986,0.00835718,0.036156062,0.03694163,-0.062062223,-0.06127477,-0.01934735,-0.031283908,0.08200542,-0.01270972,0.034525167,-0.040805645,0.035700735,-0.0045999265,0.0046523884,0.042981688,-0.012991904,0.121362366,0.018091332,-0.0011933425,-0.08453604,-0.023377812,0.0079048,-0.0118498225,-0.0031084812,-0.035165552,0.029298317,0.020293664,0.06833946,0.073024675,0.025958005,0.055193905,-0.0073304893,-0.08285115,0.012639976,-0.016050108,0.017499002,-0.070264466,-0.01374525,0.084155224,0.08962586,0.08847589,0.023961196,-0.028216874,-0.016020639,0.051627345,0.021587811,-0.017810969,0.09389319,-0.07359883,0.04477541,-0.040727414]

# %%
list_of_lists = [list_99249, list_7537, list_6028, list_141539, list_259669]
print(list_of_lists)

# %%
index_99249 = [99249]
index_7537 = [7537]
index_6028 = [6028]
index_141539 = [141539]
index_259669 = [259669]
indexes = index_99249 + index_7537 + index_6028 + index_141539 + index_259669

# %%
# Step 4: Calculate the cosine similarity matrix
similarity_matrix_list = cosine_similarity(list_of_lists, event_vectors)

# %%
# Step 5: Create df
similarity_df_list = pd.DataFrame(similarity_matrix_list,
                             index=indexes,
                             columns=event_embeddings['EventCode'])

# %%
similarity_df_list

# %%
similarity_df_list.T
