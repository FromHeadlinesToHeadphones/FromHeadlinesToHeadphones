# %%
import pandas as pd
import gdown

import matplotlib.pyplot as plt

# %%
url_events_gdelt = 'https://drive.google.com/file/d/1hFhAQy2lucdIYBNSTL2fLR5syeT3utjw/view?usp=sharing'
path_gdelts_id = url_events_gdelt.split('/')[-2]
path_gdelt = f"https://drive.google.com/uc?id={path_gdelts_id}"
gdown.download(path_gdelt, 'gdelt_event_counts_1990_2024.csv', quiet=False)

# songs_embedded_df = pd.read_csv(path_songs)
gdelt_df = pd.read_csv('gdelt_event_counts_1990_2024.csv')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hFhAQy2lucdIYBNSTL2fLR5syeT3utjw
# To: /content/gdelt_event_counts_1990_2024.csv
# 100%|██████████| 92.6k/92.6k [00:00<00:00, 61.0MB/s]

# %%
gdelt_df
# Out:
#       Year  Month  EventCode  count
# 0     1990      1        161    387
# 1     1990      1        163    120
# 2     1990      1        174    214
# 3     1990      1        175     63
# 4     1990      1        190   4622
# ...    ...    ...        ...    ...
# 5954  2024     12        201     48
# 5955  2024     12        202    803
# 5956  2024     12        203   1057
# 5957  2024     12       1413     17
# 5958  2024     12       1431      1
#
# [5959 rows x 4 columns]

# %%
gdelt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5959 entries, 0 to 5958
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       5959 non-null   int64
#  1   Month      5959 non-null   int64
#  2   EventCode  5959 non-null   int64
#  3   count      5959 non-null   int64
# dtypes: int64(4)
# memory usage: 186.3 KB

# %%
gdelt_df['date'] = pd.to_datetime(gdelt_df['Year'].astype(str) + '-' + gdelt_df['Month'].astype(str) + '-01')

# %%
gdelt_df['date']
# Out:
# 0      1990-01-01
# 1      1990-01-01
# 2      1990-01-01
# 3      1990-01-01
# 4      1990-01-01
#           ...
# 5954   2024-12-01
# 5955   2024-12-01
# 5956   2024-12-01
# 5957   2024-12-01
# 5958   2024-12-01
# Name: date, Length: 5959, dtype: datetime64[ns]

# %%
event_codes = gdelt_df['EventCode'].unique()

# %%
event_codes
# Out:
# array([ 161,  163,  174,  175,  190,  191,  192,  193,  194,  201,  202,
#        1431,  196,  203, 1413, 1414])
